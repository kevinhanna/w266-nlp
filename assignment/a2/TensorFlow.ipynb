# %%
# !pip install -q tensorflow==2.0.0-alpha0

# %% [markdown]
# # Machine Learning in TensorFlow
#
# ### Brief Review of Machine Learning
#
# In supervised learning, parametric models are those where the model is a function of a fixed form with a number of unknown _parameters_.  Together with a loss function and a training set, an optimizer can select parameters to minimize the loss with respect to the training set.  Common optimizers include stochastic gradient descent.  It tweaks the parameters slightly to move the loss "downhill" due to a small batch of examples from the training set.
#
# ### Linear & Logistic Regression
#
# You've likely seen linear regression before.  In linear regression, we fit a line (technically, hyperplane) that predicts a target variable, $y$, based on some features $x$.  The form of this model is affine (even if we call it "linear"):
#
# $$y_{hat} = xW + b$$
#
# where $W$ and $b$ are weights and an offset, respectively, and are the parameters of this parametric model.  The loss function that the optimizer uses to fit these parameters is the squared error ($||\cdots||_2$) between the prediction and the ground truth in the training set.
#
# You've also likely seen logistic regression, which is tightly related to linear regression.  Logistic regression also fits a line - this time separating the positive and negative examples of a binary classifier.  The form of this model is similar:
#
# $$y_{hat} = \sigma(xW + b)$$
#
# where again $W$ and $b$ are the parameters of this model, and $\sigma$ is the [sigmoid function](https://en.wikipedia.org/wiki/Sigmoid_function) which maps un-normalized scores ("logits") to values $\hat{y} \in [0,1]$ that represent probabilities. The loss function that the optimizer uses to fit these parameters is the [cross entropy](../information_theory.ipynb) between the prediction and the ground truth in the training set.
#
# This pattern of an affine transform, $xW + b$, occurs over and over in machine learning.
#
# ### Preliminaries...
#
# Before we do anything else, let's load our data and take a quick look at it.  In this example, we're going to build a (very) simple binary classifier based on two floating point features.

# %%
import data
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
X_train, y_train, X_test, y_test = data.generate_data(1000, 10)
print(X_train.shape)
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='bwr');
# Out:
# (1000, 2)

# %% [markdown]
# ### Training Logistic Regression
#
# It's clear that the data is separable with a vertical line.  The simplest model we can use for this data is logistic regression.  Let's do that.
#
# Make sure the next cell outputs 2.0.0-alpha0.  If it doesn't, run the top cell of this notebook again.

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
# Sequential models are ones where the set of specified layers are stacked each on top of the previous.
linear_model = keras.Sequential([
    # Dense is an affine (xW + b) layer followed by an element wise nonlinearity.
    keras.layers.Dense(1, activation='sigmoid')
])

# adam optimizer is a fancier version of gradient descent.  You can read more about it here: https://arxiv.org/pdf/1412.6980.pdf
linear_model.compile(optimizer='adam',
              loss='binary_crossentropy',  # From information theory notebooks.
              metrics=['accuracy'])        # What metric to output as we train.

linear_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 134us/sample - loss: 1.0185 - accuracy: 0.1350
# Epoch 2/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.9746 - accuracy: 0.1380
# Epoch 3/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.9328 - accuracy: 0.1440
# Epoch 4/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8932 - accuracy: 0.1600
# Epoch 5/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8551 - accuracy: 0.1750
# Epoch 6/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8197 - accuracy: 0.2000
# Epoch 7/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7860 - accuracy: 0.2450
# Epoch 8/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7542 - accuracy: 0.3070
# Epoch 9/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7246 - accuracy: 0.4030
# Epoch 10/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6966 - accuracy: 0.5100
# Epoch 11/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6700 - accuracy: 0.6080
# Epoch 12/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6447 - accuracy: 0.6930
# Epoch 13/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6211 - accuracy: 0.7750
# Epoch 14/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.5987 - accuracy: 0.8140
# Epoch 15/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.5774 - accuracy: 0.8470
# Epoch 16/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5573 - accuracy: 0.8830
# Epoch 17/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5382 - accuracy: 0.9070
# Epoch 18/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5202 - accuracy: 0.9260
# Epoch 19/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5031 - accuracy: 0.9330
# Epoch 20/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4869 - accuracy: 0.9410
# Epoch 21/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4714 - accuracy: 0.9480
# Epoch 22/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4567 - accuracy: 0.9550
# Epoch 23/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4428 - accuracy: 0.9560
# Epoch 24/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4297 - accuracy: 0.9590
# Epoch 25/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4171 - accuracy: 0.9640
# Epoch 26/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4052 - accuracy: 0.9650
# Epoch 27/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3939 - accuracy: 0.9660
# Epoch 28/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3831 - accuracy: 0.9670
# Epoch 29/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.3728 - accuracy: 0.9670
# Epoch 30/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.3630 - accuracy: 0.9650
# Epoch 31/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3537 - accuracy: 0.9690
# Epoch 32/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3447 - accuracy: 0.9700
# Epoch 33/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3362 - accuracy: 0.9700
# Epoch 34/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.3280 - accuracy: 0.9720
# Epoch 35/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.3202 - accuracy: 0.9720
# Epoch 36/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3127 - accuracy: 0.9710
# Epoch 37/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3056 - accuracy: 0.9720
# Epoch 38/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2987 - accuracy: 0.9720
# Epoch 39/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2921 - accuracy: 0.9740
# Epoch 40/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2858 - accuracy: 0.9740
# Epoch 41/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2797 - accuracy: 0.9730
# Epoch 42/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2738 - accuracy: 0.9730
# Epoch 43/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2682 - accuracy: 0.9750
# Epoch 44/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2629 - accuracy: 0.9760
# Epoch 45/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.96 - 0s 29us/sample - loss: 0.2576 - accuracy: 0.9750
# Epoch 46/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2526 - accuracy: 0.9750
# Epoch 47/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2478 - accuracy: 0.9760
# Epoch 48/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2432 - accuracy: 0.9760
# Epoch 49/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2388 - accuracy: 0.9760
# Epoch 50/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2344 - accuracy: 0.9760
# Epoch 51/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2303 - accuracy: 0.9770
# Epoch 52/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2262 - accuracy: 0.9790
# Epoch 53/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2223 - accuracy: 0.9790
# Epoch 54/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2185 - accuracy: 0.9790
# Epoch 55/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2149 - accuracy: 0.9790
# Epoch 56/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2114 - accuracy: 0.9790
# Epoch 57/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2079 - accuracy: 0.9790
# Epoch 58/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2046 - accuracy: 0.9790
# Epoch 59/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2014 - accuracy: 0.9790
# Epoch 60/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1983 - accuracy: 0.9790
# Epoch 61/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1953 - accuracy: 0.9790
# Epoch 62/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1924 - accuracy: 0.9800
# Epoch 63/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1895 - accuracy: 0.9800
# Epoch 64/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1868 - accuracy: 0.9800
# Epoch 65/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1841 - accuracy: 0.9800
# Epoch 66/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1815 - accuracy: 0.9800
# Epoch 67/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1790 - accuracy: 0.9800
# Epoch 68/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1765 - accuracy: 0.9800
# Epoch 69/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1742 - accuracy: 0.9800
# Epoch 70/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1718 - accuracy: 0.9800
# Epoch 71/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1696 - accuracy: 0.9800
# Epoch 72/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1674 - accuracy: 0.9800
# Epoch 73/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1652 - accuracy: 0.9800
# Epoch 74/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1631 - accuracy: 0.9800
# Epoch 75/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1611 - accuracy: 0.9800
# Epoch 76/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1592 - accuracy: 0.9810
# Epoch 77/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1572 - accuracy: 0.9810
# Epoch 78/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1554 - accuracy: 0.9810
# Epoch 79/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1535 - accuracy: 0.9810
# Epoch 80/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1517 - accuracy: 0.9810
# Epoch 81/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1500 - accuracy: 0.9810
# Epoch 82/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1483 - accuracy: 0.9810
# Epoch 83/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1466 - accuracy: 0.9810
# Epoch 84/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1450 - accuracy: 0.9820
# Epoch 85/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1434 - accuracy: 0.9810
# Epoch 86/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1419 - accuracy: 0.9820
# Epoch 87/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1404 - accuracy: 0.9810
# Epoch 88/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1389 - accuracy: 0.9810
# Epoch 89/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1375 - accuracy: 0.9810
# Epoch 90/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1361 - accuracy: 0.9810
# Epoch 91/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1347 - accuracy: 0.9810
# Epoch 92/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1333 - accuracy: 0.9810
# Epoch 93/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1320 - accuracy: 0.9810
# Epoch 94/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1307 - accuracy: 0.9810
# Epoch 95/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.1295 - accuracy: 0.9810
# Epoch 96/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1282 - accuracy: 0.9810
# Epoch 97/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1270 - accuracy: 0.9810
# Epoch 98/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1258 - accuracy: 0.9810
# Epoch 99/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1247 - accuracy: 0.9810
# Epoch 100/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.1236 - accuracy: 0.9810

# %% [markdown]
# **Hint:** You should expect to see an initial loss here of 0.2 - 1.0.  This is because a well-initialized random classifier tends to output a uniform distribution.  For each example in the batch, we either compute the cross-entropy loss of the label (`[1, 0]` or `[0, 1]`) against the model's output (`~[0.5, 0.5]`).  Both cases result in $-\ln(0.5) = ln(2) = 0.69$.
#
# Of course, your random classifier won't output exactly uniform distributions (it's random after all), but you should anticipate it being pretty close.  If it's not, your initialization may be broken and make it hard for your network to learn.
#
# **[Optional]** Some technical details... if your randomly initialized network is outputting very confident predictions, the loss computed may be very large while at the same time the sigmoids in the network are likely in saturation, quickly shrinking gradients.  The result is that you make tiny updates in the face of a huge loss.
#
# Let's use our model to make predictions on the test set:

# %%
predictions = linear_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# ### But what about a harder problem?
#
# The case above, the data was linearly separable making it susceptible to a linear classifier.
#
# But what if you had data that looked more like this?

# %%
X_train, y_train, X_test, y_test = data.generate_non_linear_data(1000, 10)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test, cmap='bwr')

# %%
linear_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 33us/sample - loss: 1.7626 - accuracy: 0.6660
# Epoch 2/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.6467 - accuracy: 0.6740
# Epoch 3/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.5566 - accuracy: 0.6760
# Epoch 4/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.4774 - accuracy: 0.6750
# Epoch 5/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.4049 - accuracy: 0.6740
# Epoch 6/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.3381 - accuracy: 0.6740
# Epoch 7/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.2770 - accuracy: 0.6760
# Epoch 8/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.2205 - accuracy: 0.6760
# Epoch 9/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.1667 - accuracy: 0.6760
# Epoch 10/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 1.1177 - accuracy: 0.6770
# Epoch 11/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.0729 - accuracy: 0.6730
# Epoch 12/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.0307 - accuracy: 0.6790
# Epoch 13/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.9922 - accuracy: 0.6760
# Epoch 14/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.9552 - accuracy: 0.6740
# Epoch 15/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.9213 - accuracy: 0.6760
# Epoch 16/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.8908 - accuracy: 0.6750
# Epoch 17/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.8630 - accuracy: 0.6700
# Epoch 18/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.8386 - accuracy: 0.6640
# Epoch 19/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.8158 - accuracy: 0.6620
# Epoch 20/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7956 - accuracy: 0.6610
# Epoch 21/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7770 - accuracy: 0.6570
# Epoch 22/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7619 - accuracy: 0.6470
# Epoch 23/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7476 - accuracy: 0.6350
# Epoch 24/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7360 - accuracy: 0.6360
# Epoch 25/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7244 - accuracy: 0.6200
# Epoch 26/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7149 - accuracy: 0.6150
# Epoch 27/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7072 - accuracy: 0.5910
# Epoch 28/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7003 - accuracy: 0.5850
# Epoch 29/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6947 - accuracy: 0.5680
# Epoch 30/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6898 - accuracy: 0.5560
# Epoch 31/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6859 - accuracy: 0.5440
# Epoch 32/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6827 - accuracy: 0.5200
# Epoch 33/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6798 - accuracy: 0.5070
# Epoch 34/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6776 - accuracy: 0.5000
# Epoch 35/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6758 - accuracy: 0.4910
# Epoch 36/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.50 - 0s 29us/sample - loss: 0.6742 - accuracy: 0.4870
# Epoch 37/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6730 - accuracy: 0.4830
# Epoch 38/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6719 - accuracy: 0.4760
# Epoch 39/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6713 - accuracy: 0.4710
# Epoch 40/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6707 - accuracy: 0.4690
# Epoch 41/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6702 - accuracy: 0.4670
# Epoch 42/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6698 - accuracy: 0.4670
# Epoch 43/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6694 - accuracy: 0.4670
# Epoch 44/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6691 - accuracy: 0.4610
# Epoch 45/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6689 - accuracy: 0.4560
# Epoch 46/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6687 - accuracy: 0.4530
# Epoch 47/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6686 - accuracy: 0.4580
# Epoch 48/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6684 - accuracy: 0.4540
# Epoch 49/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6684 - accuracy: 0.4550
# Epoch 50/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6684 - accuracy: 0.4560
# Epoch 51/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6682 - accuracy: 0.4540
# Epoch 52/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6681 - accuracy: 0.4580
# Epoch 53/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6681 - accuracy: 0.4580
# Epoch 54/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6681 - accuracy: 0.4600
# Epoch 55/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4550
# Epoch 56/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6681 - accuracy: 0.4590
# Epoch 57/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4560
# Epoch 58/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4630
# Epoch 59/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4620
# Epoch 60/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6681 - accuracy: 0.4690
# Epoch 61/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4660
# Epoch 62/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4670
# Epoch 63/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.4670
# Epoch 64/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6679 - accuracy: 0.4650
# Epoch 65/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4750
# Epoch 66/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4780
# Epoch 67/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4800
# Epoch 68/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4840
# Epoch 69/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.7125 - accuracy: 0.43 - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4770
# Epoch 70/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4780
# Epoch 71/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4870
# Epoch 72/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4870
# Epoch 73/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6678 - accuracy: 0.4890
# Epoch 74/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6679 - accuracy: 0.4880
# Epoch 75/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4900
# Epoch 76/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.6679 - accuracy: 0.4920
# Epoch 77/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4900
# Epoch 78/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6679 - accuracy: 0.4910
# Epoch 79/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4890
# Epoch 80/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4920
# Epoch 81/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4930
# Epoch 82/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4920
# Epoch 83/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4880
# Epoch 84/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4840
# Epoch 85/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6679 - accuracy: 0.4830
# Epoch 86/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.6679 - accuracy: 0.4850
# Epoch 87/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6678 - accuracy: 0.50 - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4890
# Epoch 88/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4960
# Epoch 89/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4990
# Epoch 90/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4930
# Epoch 91/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4930
# Epoch 92/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4910
# Epoch 93/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.5020
# Epoch 94/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6680 - accuracy: 0.5000
# Epoch 95/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6680 - accuracy: 0.5010
# Epoch 96/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.5060
# Epoch 97/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6680 - accuracy: 0.5120
# Epoch 98/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.5010
# Epoch 99/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.5040
# Epoch 100/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.75 - 0s 31us/sample - loss: 0.6680 - accuracy: 0.5000

# %% [markdown]
# Again, let's make predictions on the test set...

# %%
predictions = linear_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# That isn't very good!
#
# ### Building a deeper network
#
# Ok, now it's your turn.  Build a deeper neural network below.  Try to achieve a loss less than 0.05.

# %%
deep_model = keras.Sequential([
    ### YOUR CODE HERE
    # Hint, try "relu" as your activation function.
    # This is the most common nonlinearity for the main body of the network as its derivative is identically 1.
    # This means that the gradient doesn't tend to explode or vanish as you multiply more partial
    # derivative terms together.
    # Try toying with the trade offs between more layers vs deeper networks:
    #   How few layers can you get away with?
    #   Conversely, how small hidden vectors can you use if you use more layers?
    ### END YOUR CODE
    keras.layers.Dense(1, activation='sigmoid')
])

deep_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

deep_model.fit(X_train, y_train, epochs=100)

# %%
predictions = deep_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# # Congratulations...
# ... you've trained a nonlinear classifier with TensorFlow!
