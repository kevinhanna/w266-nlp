# %%
# !pip install -q tensorflow==2.0.0-alpha0

# %% [markdown]
# # Machine Learning in TensorFlow
#
# ### Brief Review of Machine Learning
#
# In supervised learning, parametric models are those where the model is a function of a fixed form with a number of unknown _parameters_.  Together with a loss function and a training set, an optimizer can select parameters to minimize the loss with respect to the training set.  Common optimizers include stochastic gradient descent.  It tweaks the parameters slightly to move the loss "downhill" due to a small batch of examples from the training set.
#
# ### Linear & Logistic Regression
#
# You've likely seen linear regression before.  In linear regression, we fit a line (technically, hyperplane) that predicts a target variable, $y$, based on some features $x$.  The form of this model is affine (even if we call it "linear"):
#
# $$y_{hat} = xW + b$$
#
# where $W$ and $b$ are weights and an offset, respectively, and are the parameters of this parametric model.  The loss function that the optimizer uses to fit these parameters is the squared error ($||\cdots||_2$) between the prediction and the ground truth in the training set.
#
# You've also likely seen logistic regression, which is tightly related to linear regression.  Logistic regression also fits a line - this time separating the positive and negative examples of a binary classifier.  The form of this model is similar:
#
# $$y_{hat} = \sigma(xW + b)$$
#
# where again $W$ and $b$ are the parameters of this model, and $\sigma$ is the [sigmoid function](https://en.wikipedia.org/wiki/Sigmoid_function) which maps un-normalized scores ("logits") to values $\hat{y} \in [0,1]$ that represent probabilities. The loss function that the optimizer uses to fit these parameters is the [cross entropy](../information_theory.ipynb) between the prediction and the ground truth in the training set.
#
# This pattern of an affine transform, $xW + b$, occurs over and over in machine learning.
#
# ### Preliminaries...
#
# Before we do anything else, let's load our data and take a quick look at it.  In this example, we're going to build a (very) simple binary classifier based on two floating point features.

# %%
import data
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
X_train, y_train, X_test, y_test = data.generate_data(1000, 10)
print(X_train.shape)
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap='bwr');
# Out:
# (1000, 2)

# %% [markdown]
# ### Training Logistic Regression
#
# It's clear that the data is separable with a vertical line.  The simplest model we can use for this data is logistic regression.  Let's do that.
#
# Make sure the next cell outputs 2.0.0-alpha0.  If it doesn't, run the top cell of this notebook again.

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.0.0-alpha0

# %%
# Sequential models are ones where the set of specified layers are stacked each on top of the previous.
linear_model = keras.Sequential([
    # Dense is an affine (xW + b) layer followed by an element wise nonlinearity.
    keras.layers.Dense(1, activation='sigmoid')
])

# adam optimizer is a fancier version of gradient descent.  You can read more about it here: https://arxiv.org/pdf/1412.6980.pdf
linear_model.compile(optimizer='adam',
              loss='binary_crossentropy',  # From information theory notebooks.
              metrics=['accuracy'])        # What metric to output as we train.

linear_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 129us/sample - loss: 2.6905 - accuracy: 0.1050
# Epoch 2/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 2.6274 - accuracy: 0.1040
# Epoch 3/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.5647 - accuracy: 0.1040
# Epoch 4/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.5025 - accuracy: 0.1020
# Epoch 5/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.4399 - accuracy: 0.1000
# Epoch 6/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.3787 - accuracy: 0.0990
# Epoch 7/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.3174 - accuracy: 0.0970
# Epoch 8/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.2568 - accuracy: 0.0970
# Epoch 9/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.1977 - accuracy: 0.1000
# Epoch 10/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.1389 - accuracy: 0.1000
# Epoch 11/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.0806 - accuracy: 0.1010
# Epoch 12/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 2.0222 - accuracy: 0.1010
# Epoch 13/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.9657 - accuracy: 0.1000
# Epoch 14/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.9092 - accuracy: 0.1000
# Epoch 15/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.8537 - accuracy: 0.0970
# Epoch 16/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.7987 - accuracy: 0.0980
# Epoch 17/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.7448 - accuracy: 0.0970
# Epoch 18/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.6918 - accuracy: 0.0950
# Epoch 19/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.6394 - accuracy: 0.0990
# Epoch 20/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.5888 - accuracy: 0.0980
# Epoch 21/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.5382 - accuracy: 0.1000
# Epoch 22/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.4886 - accuracy: 0.0980
# Epoch 23/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.4404 - accuracy: 0.0980
# Epoch 24/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.3930 - accuracy: 0.0990
# Epoch 25/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.3467 - accuracy: 0.1010
# Epoch 26/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.3022 - accuracy: 0.1060
# Epoch 27/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.2585 - accuracy: 0.1120
# Epoch 28/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.2171 - accuracy: 0.1160
# Epoch 29/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.1766 - accuracy: 0.1220
# Epoch 30/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.1369 - accuracy: 0.1290
# Epoch 31/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.0989 - accuracy: 0.1350
# Epoch 32/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.0623 - accuracy: 0.1410
# Epoch 33/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.0266 - accuracy: 0.1500
# Epoch 34/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.9925 - accuracy: 0.1640
# Epoch 35/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.9594 - accuracy: 0.1730
# Epoch 36/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.9276 - accuracy: 0.1870
# Epoch 37/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.8969 - accuracy: 0.2190
# Epoch 38/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.8674 - accuracy: 0.2430
# Epoch 39/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8393 - accuracy: 0.2790
# Epoch 40/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8123 - accuracy: 0.3150
# Epoch 41/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7864 - accuracy: 0.3450
# Epoch 42/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7616 - accuracy: 0.3980
# Epoch 43/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7379 - accuracy: 0.4380
# Epoch 44/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7152 - accuracy: 0.4820
# Epoch 45/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6933 - accuracy: 0.5310
# Epoch 46/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6724 - accuracy: 0.5750
# Epoch 47/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6523 - accuracy: 0.6120
# Epoch 48/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6330 - accuracy: 0.6500
# Epoch 49/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6145 - accuracy: 0.6890
# Epoch 50/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5969 - accuracy: 0.7270
# Epoch 51/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.5800 - accuracy: 0.7770
# Epoch 52/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.5639 - accuracy: 0.7980
# Epoch 53/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5483 - accuracy: 0.8210
# Epoch 54/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.5336 - accuracy: 0.8460
# Epoch 55/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5193 - accuracy: 0.8670
# Epoch 56/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.5057 - accuracy: 0.8920
# Epoch 57/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.4927 - accuracy: 0.9040
# Epoch 58/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.4802 - accuracy: 0.9210
# Epoch 59/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4681 - accuracy: 0.9300
# Epoch 60/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4567 - accuracy: 0.9370
# Epoch 61/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4455 - accuracy: 0.9420
# Epoch 62/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4349 - accuracy: 0.9460
# Epoch 63/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4247 - accuracy: 0.9500
# Epoch 64/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.4149 - accuracy: 0.9550
# Epoch 65/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.4055 - accuracy: 0.9560
# Epoch 66/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3964 - accuracy: 0.9590
# Epoch 67/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3876 - accuracy: 0.9620
# Epoch 68/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3792 - accuracy: 0.9630
# Epoch 69/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3711 - accuracy: 0.9630
# Epoch 70/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3632 - accuracy: 0.9630
# Epoch 71/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3557 - accuracy: 0.9650
# Epoch 72/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3484 - accuracy: 0.9650
# Epoch 73/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3415 - accuracy: 0.9640
# Epoch 74/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3347 - accuracy: 0.9680
# Epoch 75/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3282 - accuracy: 0.9680
# Epoch 76/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3219 - accuracy: 0.9690
# Epoch 77/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.3158 - accuracy: 0.9700
# Epoch 78/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.3099 - accuracy: 0.9720
# Epoch 79/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.93 - 0s 28us/sample - loss: 0.3043 - accuracy: 0.9720
# Epoch 80/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2987 - accuracy: 0.9720
# Epoch 81/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2934 - accuracy: 0.9700
# Epoch 82/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2882 - accuracy: 0.9710
# Epoch 83/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2832 - accuracy: 0.9720
# Epoch 84/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2783 - accuracy: 0.9740
# Epoch 85/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2736 - accuracy: 0.9740
# Epoch 86/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2690 - accuracy: 0.9740
# Epoch 87/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2646 - accuracy: 0.9750
# Epoch 88/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2603 - accuracy: 0.9760
# Epoch 89/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2562 - accuracy: 0.9760
# Epoch 90/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2521 - accuracy: 0.9760
# Epoch 91/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.2482 - accuracy: 0.9760
# Epoch 92/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2443 - accuracy: 0.9760
# Epoch 93/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2406 - accuracy: 0.9760
# Epoch 94/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2370 - accuracy: 0.9760
# Epoch 95/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2335 - accuracy: 0.9760
# Epoch 96/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2301 - accuracy: 0.9760
# Epoch 97/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2267 - accuracy: 0.9780
# Epoch 98/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2234 - accuracy: 0.9790
# Epoch 99/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2203 - accuracy: 0.9790
# Epoch 100/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2172 - accuracy: 0.9790

# %% [markdown]
# **Hint:** You should expect to see an initial loss here of 0.2 - 1.0.  This is because a well-initialized random classifier tends to output a uniform distribution.  For each example in the batch, we either compute the cross-entropy loss of the label (`[1, 0]` or `[0, 1]`) against the model's output (`~[0.5, 0.5]`).  Both cases result in $-\ln(0.5) = ln(2) = 0.69$.
#
# Of course, your random classifier won't output exactly uniform distributions (it's random after all), but you should anticipate it being pretty close.  If it's not, your initialization may be broken and make it hard for your network to learn.
#
# **[Optional]** Some technical details... if your randomly initialized network is outputting very confident predictions, the loss computed may be very large while at the same time the sigmoids in the network are likely in saturation, quickly shrinking gradients.  The result is that you make tiny updates in the face of a huge loss.
#
# Let's use our model to make predictions on the test set:

# %%
predictions = linear_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# ### But what about a harder problem?
#
# The case above, the data was linearly separable making it susceptible to a linear classifier.
#
# But what if you had data that looked more like this?

# %%
X_train, y_train, X_test, y_test = data.generate_non_linear_data(1000, 10)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test, cmap='bwr')

# %%
linear_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 1.2074 - accuracy: 0.6480
# Epoch 2/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.1488 - accuracy: 0.6540
# Epoch 3/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.1081 - accuracy: 0.6500
# Epoch 4/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.0705 - accuracy: 0.6490
# Epoch 5/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 1.0344 - accuracy: 0.6480
# Epoch 6/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.9999 - accuracy: 0.6470
# Epoch 7/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.9677 - accuracy: 0.6490
# Epoch 8/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.9377 - accuracy: 0.6490
# Epoch 9/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.9087 - accuracy: 0.6470
# Epoch 10/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8823 - accuracy: 0.6480
# Epoch 11/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.8586 - accuracy: 0.6380
# Epoch 12/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8362 - accuracy: 0.6410
# Epoch 13/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.8161 - accuracy: 0.6320
# Epoch 14/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7969 - accuracy: 0.6230
# Epoch 15/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7797 - accuracy: 0.6250
# Epoch 16/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7646 - accuracy: 0.6200
# Epoch 17/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7512 - accuracy: 0.6090
# Epoch 18/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7398 - accuracy: 0.5950
# Epoch 19/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.7292 - accuracy: 0.5890
# Epoch 20/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7201 - accuracy: 0.5810
# Epoch 21/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7118 - accuracy: 0.5720
# Epoch 22/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.7054 - accuracy: 0.5600
# Epoch 23/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6994 - accuracy: 0.5440
# Epoch 24/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6947 - accuracy: 0.5390
# Epoch 25/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6898 - accuracy: 0.5240
# Epoch 26/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.7113 - accuracy: 0.50 - 0s 29us/sample - loss: 0.6858 - accuracy: 0.5170
# Epoch 27/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6828 - accuracy: 0.5100
# Epoch 28/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6800 - accuracy: 0.5070
# Epoch 29/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6778 - accuracy: 0.5020
# Epoch 30/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6759 - accuracy: 0.5010
# Epoch 31/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6745 - accuracy: 0.5010
# Epoch 32/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6733 - accuracy: 0.4980
# Epoch 33/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6722 - accuracy: 0.4960
# Epoch 34/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6713 - accuracy: 0.4950
# Epoch 35/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6707 - accuracy: 0.4860
# Epoch 36/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6700 - accuracy: 0.4830
# Epoch 37/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6696 - accuracy: 0.4830
# Epoch 38/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6692 - accuracy: 0.4770
# Epoch 39/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.6690 - accuracy: 0.4780
# Epoch 40/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6688 - accuracy: 0.4820
# Epoch 41/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6686 - accuracy: 0.4810
# Epoch 42/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6686 - accuracy: 0.4820
# Epoch 43/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6684 - accuracy: 0.4830
# Epoch 44/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6683 - accuracy: 0.4820
# Epoch 45/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6682 - accuracy: 0.4810
# Epoch 46/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6681 - accuracy: 0.4760
# Epoch 47/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6681 - accuracy: 0.4800
# Epoch 48/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.4830
# Epoch 49/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6681 - accuracy: 0.4820
# Epoch 50/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.7088 - accuracy: 0.40 - 0s 31us/sample - loss: 0.6681 - accuracy: 0.4820
# Epoch 51/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4800
# Epoch 52/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4810
# Epoch 53/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4830
# Epoch 54/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.7287 - accuracy: 0.37 - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4870
# Epoch 55/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4820
# Epoch 56/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.4840
# Epoch 57/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4840
# Epoch 58/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6679 - accuracy: 0.4830
# Epoch 59/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4850
# Epoch 60/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6681 - accuracy: 0.4870
# Epoch 61/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4810
# Epoch 62/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.46 - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4800
# Epoch 63/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4840
# Epoch 64/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4780
# Epoch 65/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4860
# Epoch 66/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4880
# Epoch 67/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4950
# Epoch 68/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4930
# Epoch 69/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4880
# Epoch 70/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4910
# Epoch 71/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.4940
# Epoch 72/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4910
# Epoch 73/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4940
# Epoch 74/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4910
# Epoch 75/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4940
# Epoch 76/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6679 - accuracy: 0.4970
# Epoch 77/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4950
# Epoch 78/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6679 - accuracy: 0.4990
# Epoch 79/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4930
# Epoch 80/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4940
# Epoch 81/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.5000
# Epoch 82/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4990
# Epoch 83/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.6679 - accuracy: 0.4910
# Epoch 84/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4860
# Epoch 85/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4850
# Epoch 86/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4850
# Epoch 87/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.4920
# Epoch 88/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.4960
# Epoch 89/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6679 - accuracy: 0.5030
# Epoch 90/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.4960
# Epoch 91/100
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6545 - accuracy: 0.50 - 0s 30us/sample - loss: 0.6678 - accuracy: 0.4970
# Epoch 92/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.4920
# Epoch 93/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6678 - accuracy: 0.5020
# Epoch 94/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.5010
# Epoch 95/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6680 - accuracy: 0.5030
# Epoch 96/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6680 - accuracy: 0.5060
# Epoch 97/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6680 - accuracy: 0.5120
# Epoch 98/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.5030
# Epoch 99/100
# 1000/1000 [==============================] - 0s 29us/sample - loss: 0.6678 - accuracy: 0.5040
# Epoch 100/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.6680 - accuracy: 0.5000

# %% [markdown]
# Again, let's make predictions on the test set...

# %%
predictions = linear_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# That isn't very good!
#
# ### Building a deeper network
#
# Ok, now it's your turn.  Build a deeper neural network below.  Try to achieve a loss less than 0.05.

# %%
deep_model = keras.Sequential([
    ### YOUR CODE HERE
    # Hint, try "relu" as your activation function.
    # This is the most common nonlinearity for the main body of the network as its derivative is identically 1.
    # This means that the gradient doesn't tend to explode or vanish as you multiply more partial
    # derivative terms together.
    # Try toying with the trade offs between more layers vs deeper networks:
    #   How few layers can you get away with?
    #   Conversely, how small hidden vectors can you use if you use more layers?

    keras.layers.Dense(3, activation='selu'),
    
    ### END YOUR CODE
    keras.layers.Dense(1, activation='sigmoid')
])

deep_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

deep_model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 164us/sample - loss: 0.9822 - accuracy: 0.4900
# Epoch 2/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.9061 - accuracy: 0.4930
# Epoch 3/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.8455 - accuracy: 0.4990
# Epoch 4/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7967 - accuracy: 0.5160
# Epoch 5/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7595 - accuracy: 0.5290
# Epoch 6/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.7307 - accuracy: 0.5470
# Epoch 7/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.7094 - accuracy: 0.5610
# Epoch 8/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6927 - accuracy: 0.5790
# Epoch 9/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.6800 - accuracy: 0.6110
# Epoch 10/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6704 - accuracy: 0.6480
# Epoch 11/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6628 - accuracy: 0.6710
# Epoch 12/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6569 - accuracy: 0.6830
# Epoch 13/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6512 - accuracy: 0.6940
# Epoch 14/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6454 - accuracy: 0.6960
# Epoch 15/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6392 - accuracy: 0.6980
# Epoch 16/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6324 - accuracy: 0.7010
# Epoch 17/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.6249 - accuracy: 0.7010
# Epoch 18/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6167 - accuracy: 0.7010
# Epoch 19/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.6073 - accuracy: 0.6990
# Epoch 20/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.5973 - accuracy: 0.6970
# Epoch 21/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5859 - accuracy: 0.7000
# Epoch 22/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5739 - accuracy: 0.7050
# Epoch 23/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5606 - accuracy: 0.7060
# Epoch 24/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5466 - accuracy: 0.7060
# Epoch 25/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5317 - accuracy: 0.7080
# Epoch 26/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.5154 - accuracy: 0.7120
# Epoch 27/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.4986 - accuracy: 0.7210
# Epoch 28/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.4806 - accuracy: 0.7260
# Epoch 29/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.4617 - accuracy: 0.7340
# Epoch 30/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.4421 - accuracy: 0.7830
# Epoch 31/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.4215 - accuracy: 0.8210
# Epoch 32/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.4005 - accuracy: 0.8730
# Epoch 33/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3792 - accuracy: 0.9110
# Epoch 34/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3585 - accuracy: 0.9240
# Epoch 35/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3376 - accuracy: 0.9360
# Epoch 36/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.3177 - accuracy: 0.9470
# Epoch 37/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.2987 - accuracy: 0.9510
# Epoch 38/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2807 - accuracy: 0.9530
# Epoch 39/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2640 - accuracy: 0.9590
# Epoch 40/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2482 - accuracy: 0.9620
# Epoch 41/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2333 - accuracy: 0.9680
# Epoch 42/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2198 - accuracy: 0.9750
# Epoch 43/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.2072 - accuracy: 0.9780
# Epoch 44/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1956 - accuracy: 0.9780
# Epoch 45/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1850 - accuracy: 0.9800
# Epoch 46/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1752 - accuracy: 0.9820
# Epoch 47/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1662 - accuracy: 0.9830
# Epoch 48/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.1579 - accuracy: 0.9840
# Epoch 49/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1503 - accuracy: 0.9840
# Epoch 50/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1432 - accuracy: 0.9840
# Epoch 51/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1367 - accuracy: 0.9860
# Epoch 52/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1306 - accuracy: 0.9860
# Epoch 53/100
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.1251 - accuracy: 0.9860
# Epoch 54/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1199 - accuracy: 0.9860
# Epoch 55/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1151 - accuracy: 0.9860
# Epoch 56/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1106 - accuracy: 0.9860
# Epoch 57/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1064 - accuracy: 0.9860
# Epoch 58/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.1025 - accuracy: 0.9860
# Epoch 59/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0989 - accuracy: 0.9860
# Epoch 60/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0955 - accuracy: 0.9880
# Epoch 61/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0923 - accuracy: 0.9880
# Epoch 62/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0893 - accuracy: 0.9880
# Epoch 63/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0864 - accuracy: 0.9880
# Epoch 64/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0837 - accuracy: 0.9890
# Epoch 65/100
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.0812 - accuracy: 0.9890
# Epoch 66/100
# 1000/1000 [==============================] - 0s 34us/sample - loss: 0.0789 - accuracy: 0.9890
# Epoch 67/100
# 1000/1000 [==============================] - 0s 33us/sample - loss: 0.0766 - accuracy: 0.9890
# Epoch 68/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0744 - accuracy: 0.9890
# Epoch 69/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0724 - accuracy: 0.9890
# Epoch 70/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0705 - accuracy: 0.9890
# Epoch 71/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0687 - accuracy: 0.9890
# Epoch 72/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0670 - accuracy: 0.9890
# Epoch 73/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0653 - accuracy: 0.9890
# Epoch 74/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0637 - accuracy: 0.9890
# Epoch 75/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0623 - accuracy: 0.9890
# Epoch 76/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0608 - accuracy: 0.9890
# Epoch 77/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0594 - accuracy: 0.9890
# Epoch 78/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0581 - accuracy: 0.9890
# Epoch 79/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0569 - accuracy: 0.9900
# Epoch 80/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0557 - accuracy: 0.9900
# Epoch 81/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0546 - accuracy: 0.9900
# Epoch 82/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0534 - accuracy: 0.9900
# Epoch 83/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0523 - accuracy: 0.9900
# Epoch 84/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0513 - accuracy: 0.9900
# Epoch 85/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.0503 - accuracy: 0.9900
# Epoch 86/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0493 - accuracy: 0.9900
# Epoch 87/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0484 - accuracy: 0.9920
# Epoch 88/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0476 - accuracy: 0.9910
# Epoch 89/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0467 - accuracy: 0.9920
# Epoch 90/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0459 - accuracy: 0.9920
# Epoch 91/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0451 - accuracy: 0.9920
# Epoch 92/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0443 - accuracy: 0.9920
# Epoch 93/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0436 - accuracy: 0.9920
# Epoch 94/100
# 1000/1000 [==============================] - 0s 32us/sample - loss: 0.0429 - accuracy: 0.9920
# Epoch 95/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0422 - accuracy: 0.9920
# Epoch 96/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0415 - accuracy: 0.9930
# Epoch 97/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0408 - accuracy: 0.9930
# Epoch 98/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0402 - accuracy: 0.9930
# Epoch 99/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0396 - accuracy: 0.9930
# Epoch 100/100
# 1000/1000 [==============================] - 0s 31us/sample - loss: 0.0390 - accuracy: 0.9930

# %%
deep_model = keras.Sequential([
    ### YOUR CODE HERE
    keras.layers.Dense(1, activation='relu'),
    keras.layers.Dense(1, activation='relu'),
    keras.layers.Dense(1, activation='relu'),
    keras.layers.Dense(1, activation='relu'),
    keras.layers.Dense(1, activation='relu'),
    
    ### END YOUR CODE
    keras.layers.Dense(1, activation='sigmoid')
])

deep_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

deep_model.fit(X_train, y_train, epochs=100)
print(X_train.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-e69d5d2f6e7d> in <module>()
#      11               metrics=['accuracy'])
#      12
# ---> 13 deep_model.fit(X_train, y_train, epochs=100)
#      14 print(X_train.shape)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     804         steps=steps_per_epoch,
#     805         validation_split=validation_split,
# --> 806         shuffle=shuffle)
#     807
#     808     # Prepare validation data.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2594           feed_input_shapes,
#    2595           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2596           exception_prefix='input')
#    2597
#    2598     if y is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     347                              ': expected ' + names[i] + ' to have shape ' +
#     348                              str(shape) + ' but got array with shape ' +
# --> 349                              str(data_shape))
#     350   return data
#     351
#
# ValueError: Error when checking input: expected dense_59_input to have shape (100,) but got array with shape (2,)

# %%
predictions = deep_model.predict(X_test)
plt.scatter(X_test[:,0], X_test[:,1], c=predictions[:,0]>0.5, cmap='bwr')

# %% [markdown]
# # Congratulations...
# ... you've trained a nonlinear classifier with TensorFlow!
